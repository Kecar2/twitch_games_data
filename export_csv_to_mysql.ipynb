# %%
import pandas as pd

# %%
data = pd.read_csv('C:\\Users\\kendr\\OneDrive\\Escritorio\\Twitch_game_data.csv',encoding='cp1252', index_col=False, delimiter=',')

# %%
data.head()
# Out:
#    Rank                              Game  Month  Year  Hours_watched  \
# 0     1                 League of Legends      1  2016       94377226
# 1     2  Counter-Strike: Global Offensive      1  2016       47832863
# 2     3                            Dota 2      1  2016       45185893
# 3     4                       Hearthstone      1  2016       39936159
# 4     5       Call of Duty: Black Ops III      1  2016       16153057
#
#   Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# 0  1362044 hours        530270           2903     129172       127021
# 1   830105 hours        372654           2197     120849        64378
# 2   433397 hours        315083           1100      44074        60815
# 3   235903 hours        131357            517      36170        53749
# 4  1151578 hours         71639           3620     214054        21740
#
#    Avg_channels  Avg_viewer_ratio
# 0          1833             69.29
# 1          1117             57.62
# ...

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = msql.connect(host='localhost', user='root',  
                        password='')#give ur username, password
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("CREATE DATABASE Twitch")
        print("Database is created")
except Error as e:
    print("Error while connecting to MySQL", e)
# Out:
# Database is created

# %%
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = msql.connect(host='localhost',database='twitch', user='root',  
                        password='')#give ur username, password
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS twitch_data;')
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
        cursor.execute("CREATE TABLE twitch_data(rank int(200),game varchar(255),month varchar(255),year int(10),hours_watched int(200),hours_stremed varchar(255),peak_viewers int(200),peak_channels int(200),streamers int(200),avg_viewers int(200),avg_channels int(200),avg_viewer_ratio int(200))")
        print("Table is created....")
        #loop through the data frame
        for i,row in data.iterrows():
            #here %S means string values 
            sql = "INSERT INTO twitch.twitch_data VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('twitch',)
# Creating table....
# Table is created....
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
# Execute query
sql = "SELECT * FROM twitch.twitch_data"
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (1, 'League of Legends', '1', 2016, 94377226, '1362044 hours', 530270, 2903, 129172, 127021, 1833, 69)
# (2, 'Counter-Strike: Global Offensive', '1', 2016, 47832863, '830105 hours', 372654, 2197, 120849, 64378, 1117, 58)
# (3, 'Dota 2', '1', 2016, 45185893, '433397 hours', 315083, 1100, 44074, 60815, 583, 104)
# (4, 'Hearthstone', '1', 2016, 39936159, '235903 hours', 131357, 517, 36170, 53749, 317, 169)
# (5, 'Call of Duty: Black Ops III', '1', 2016, 16153057, '1151578 hours', 71639, 3620, 214054, 21740, 1549, 14)
# (6, 'Minecraft', '1', 2016, 10231056, '490002 hours', 64432, 1538, 88820, 13769, 659, 21)
# (7, 'World of Warcraft', '1', 2016, 8771452, '342978 hours', 46130, 1180, 33375, 11805, 461, 26)
# (8, 'Z1: Battle Royale', '1', 2016, 7894571, '205569 hours', 41588, 460, 21396, 10625, 276, 38)
# (9, 'Talk Shows & Podcasts', '1', 2016, 7688369, '53235 hours', 84051, 148, 10779, 10347, 71, 144)
# ...

# %%
sql = "SELECT * FROM twitch.twitch_data ORDER BY year DESC"
cursor.execute(sql)
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# (1, 'Fortnite', '1', 2019, 126502656, '10205058 hours', 649136, 56274, 1013016, 170259, 13734, 12)
# (2, 'League of Legends', '1', 2019, 98976171, '2245379 hours', 400257, 6079, 197058, 133211, 3022, 44)
# (3, 'Just Chatting', '1', 2019, 59064487, '803672 hours', 184542, 1757, 134201, 79494, 1081, 73)
# (4, 'Dota 2', '1', 2019, 46512393, '546394 hours', 444825, 1462, 42722, 62600, 735, 85)
# (5, 'Counter-Strike: Global Offensive', '1', 2019, 30778297, '1051447 hours', 187678, 2895, 159310, 41424, 1415, 29)
# (6, "PLAYERUNKNOWN'S BATTLEGROUNDS", '1', 2019, 29852076, '1234877 hours', 127809, 2604, 117981, 40177, 1662, 24)
# (7, 'Hearthstone', '1', 2019, 24477856, '172747 hours', 92702, 365, 21526, 32944, 232, 142)
# (8, 'Overwatch', '1', 2019, 22499093, '1192726 hours', 88234, 2784, 146158, 30281, 1605, 19)
# (9, 'FIFA 19', '1', 2019, 18618028, '355185 hours', 284483, 1434, 61024, 25057, 478, 52)
# ...
